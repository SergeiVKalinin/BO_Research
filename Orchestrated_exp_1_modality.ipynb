# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/BO_Research/blob/master/Orchestrated_exp_1_modality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Singe modality orchestrated experiment
#
# @prepared Boris Slautin
#
# @supervision Sergei Kalinin
#
# @data ...
#
# 12/23/2023

# %%
# !pip install --upgrade git+https://github.com/ziatdinovmax/pyroved.git
# !pip install git+https://github.com/ziatdinovmax/gpax@main

# !pip install mycolorpy
# Out:
# Collecting git+https://github.com/ziatdinovmax/pyroved.git
#   Cloning https://github.com/ziatdinovmax/pyroved.git to /tmp/pip-req-build-yp5ks7ye
#   Running command git clone --filter=blob:none --quiet https://github.com/ziatdinovmax/pyroved.git /tmp/pip-req-build-yp5ks7ye
#   Resolved https://github.com/ziatdinovmax/pyroved.git to commit ce8474689b716041873f4c18e1c22b2b60d6ba91
#   Preparing metadata (setup.py) ... done
# Collecting pyro-ppl>=1.6.0 (from pyroved==0.3.0)
#   Downloading pyro_ppl-1.8.6-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2 in /usr/local/lib/python3.10/dist-packages (from pyroved==0.3.0) (3.7.1)
# Requirement already satisfied: torchvision>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pyroved==0.3.0) (0.16.0+cu121)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->pyroved==0.3.0) (2.8.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.6.0->pyroved==0.3.0) (3.3.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.6.0->pyroved==0.3.0)
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.6.0->pyroved==0.3.0) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.6.0->pyroved==0.3.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.7.0->pyroved==0.3.0) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2->pyroved==0.3.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.7.0->pyroved==0.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.7.0->pyroved==0.3.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.7.0->pyroved==0.3.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.7.0->pyroved==0.3.0) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pyro-ppl>=1.6.0->pyroved==0.3.0) (1.3.0)
# Building wheels for collected packages: pyroved
#   Building wheel for pyroved (setup.py) ... done
#   Created wheel for pyroved: filename=pyroved-0.3.0-py3-none-any.whl size=48256 sha256=a3c2b7739d5ef8d6ecc8eaa0b3b822255555a3f2b87dd0967e38d5e67b35f51d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aqe2p9ar/wheels/16/b8/27/0fe349f9d2ed1b453affc74e27238f90834b88ab4dda5734da
# Successfully built pyroved
# Installing collected packages: pyro-api, pyro-ppl, pyroved
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.8.6 pyroved-0.3.0
# Collecting git+https://github.com/ziatdinovmax/gpax@main
#   Cloning https://github.com/ziatdinovmax/gpax (to revision main) to /tmp/pip-req-build-ouueizkj
#   Running command git clone --filter=blob:none --quiet https://github.com/ziatdinovmax/gpax /tmp/pip-req-build-ouueizkj
#   Resolved https://github.com/ziatdinovmax/gpax to commit 57882c97ca3afa13e8363026dc9d97c59758a512
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jax>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from gpax==0.1.1) (0.4.23)
# Collecting numpyro>=0.11.0 (from gpax==0.1.1)
#   Downloading numpyro-0.13.2-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.7/312.7 kB 2.3 MB/s eta 0:00:00
# Collecting dm-haiku>=0.0.5 (from gpax==0.1.1)
#   Downloading dm_haiku-0.0.11-py3-none-any.whl (370 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.0/371.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from gpax==0.1.1) (3.7.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from dm-haiku>=0.0.5->gpax==0.1.1) (1.4.0)
# Collecting jmp>=0.0.2 (from dm-haiku>=0.0.5->gpax==0.1.1)
#   Downloading jmp-0.0.4-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from dm-haiku>=0.0.5->gpax==0.1.1) (1.23.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from dm-haiku>=0.0.5->gpax==0.1.1) (0.9.0)
# Requirement already satisfied: flax>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from dm-haiku>=0.0.5->gpax==0.1.1) (0.7.5)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.8->gpax==0.1.1) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.8->gpax==0.1.1) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.8->gpax==0.1.1) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->gpax==0.1.1) (2.8.2)
# Requirement already satisfied: jaxlib>=0.4.14 in /usr/local/lib/python3.10/dist-packages (from numpyro>=0.11.0->gpax==0.1.1) (0.4.23+cuda12.cudnn89)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from numpyro>=0.11.0->gpax==0.1.1) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from numpyro>=0.11.0->gpax==0.1.1) (4.66.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (1.0.7)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.1.7)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.4.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.1.45)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (13.7.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (4.5.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (6.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->gpax==0.1.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (2.16.1)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.1.7)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (1.6.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (1.5.8)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (3.20.3)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku>=0.0.5->gpax==0.1.1) (3.17.0)
# Building wheels for collected packages: gpax
#   Building wheel for gpax (pyproject.toml) ... done
#   Created wheel for gpax: filename=gpax-0.1.1-py3-none-any.whl size=83404 sha256=9d1a77c8068812a92a0d210298cbcebb13efd2e5939eca9ec725c3e36210829c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-elw_n4i2/wheels/74/4e/92/c3e8de99a722e340a983319b0cc086a6a757f136ef9ac9faae
# Successfully built gpax
# Installing collected packages: jmp, numpyro, dm-haiku, gpax
# Successfully installed dm-haiku-0.0.11 gpax-0.1.1 jmp-0.0.4 numpyro-0.13.2
# Collecting mycolorpy
#   Downloading mycolorpy-1.5.1.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)
# Building wheels for collected packages: mycolorpy
#   Building wheel for mycolorpy (setup.py) ... done
#   Created wheel for mycolorpy: filename=mycolorpy-1.5.1-py3-none-any.whl size=3851 sha256=800e05a0385055a6a4c198d7ef6c648780bff4cd8a7ceb22acdd092aa6ee40c3
#   Stored in directory: /root/.cache/pip/wheels/d6/1d/04/f8bfb8b04e3daba330b3f377c041b89304271ff98fb6704946
# Successfully built mycolorpy
# Installing collected packages: mycolorpy
# Successfully installed mycolorpy-1.5.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp

import h5py

import torch
import pyroved as pv

from IPython.core.display import Video
import imageio

import gpax
import numpyro
gpax.utils.enable_x64()

from google.colab import drive

import numpyro.distributions as dist
import jax.numpy as jnp

# %%
def normalize(data):
  return [np.min(data),np.ptp(data)], (data - np.min(data))/(np.ptp(data))

# %% [markdown]
# ## Ground truth dataset
#
# <font color = 'crimson'>`Change this part with your own dataset`</font>

# %%
#loops
# !gdown https://drive.google.com/uc?id=1rKE6d4T-JHlNOT0K4HExOM83PTHPdy-2 -O /content/90nm.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rKE6d4T-JHlNOT0K4HExOM83PTHPdy-2
# To: /content/90nm.zip
# 100% 220M/220M [00:06<00:00, 36.3MB/s]

# %%
# !unzip -q /content/90nm.zip -d /content

# %%
# Load all 94*3 loops
all_loops = []


for comp in range (94):
  com_loops = []
  com_coord = []
  for loopnum in range (3):
    hf = h5py.File(r'/content/90nm/BEPS_composition{}_loop{}_0.hf5'.format(comp, loopnum), 'r+')
    beps_qf = hf["BE Quick Fitting/Quick Fitting/Quick Fitting"]
    beps_wv = np.asarray(hf["BEPS/vdc_waveform"])

    com_loops.append(beps_qf[0])
  all_loops.append(com_loops)
all_loops = np.asarray(all_loops)

# %%
# correct phase
pha = all_loops[:,:,-1]
mi = np.min(pha)
ma = np.max(pha)

correct_pha = np.where(pha > 1.6, pha + (mi-ma), pha)

correct_pha = correct_pha + np.pi - 1.25
all_loops[:,:,-1] = correct_pha
mean_loops, std_loops = all_loops.mean(1), all_loops.std(1)

# %%
# Separate on field and off field loops
loops_on = np.zeros((94, 4, len(beps_wv)))
loops_off = np.zeros((94, 4, len(beps_wv)))

for k in range (len(beps_wv)):
  loops_on[:, :, k] = mean_loops[:, :, 2*k]
  loops_off[:, :, k] = mean_loops[:, :, 1+2*k]

# %%
poly_on = loops_on[:,0]*np.cos(loops_on[:,3])
poly_off = loops_off[:,0]*np.cos(loops_off[:,3])

freq_on = loops_on[:,1]
freq_off = loops_off[:,1]

# %%
l1,l2 = poly_on.shape
beps_wv_s = beps_wv[:len(beps_wv)//5]

poly_on_s = poly_on.reshape(l1,5,l2//5).mean(1)
poly_off_s = poly_off.reshape(l1,5,l2//5).mean(1)

freq_on_s = freq_on.reshape(l1,5,l2//5).mean(1)
freq_off_s = freq_off.reshape(l1,5,l2//5).mean(1)

# %%
color=mcp.gen_color(cmap="jet",n=94)

fig, ax = plt.subplots(15,4, figsize=(15,25), constrained_layout=True)

ax[0,0].set_title('PFM off', fontsize=18)
ax[0,1].set_title('Frequency off', fontsize=18)
ax[0,2].set_title('PFM on', fontsize=18)
ax[0,3].set_title('Frequency on', fontsize=18)

for i, _ax in enumerate(ax):
  _poly_off = poly_off[l1//15*i]*1E5
  _poly_on = poly_on[l1//15*i]*1E5

  _freq_off = freq_off[l1//15*i]/1E3
  _freq_on = freq_on[l1//15*i]/1E3

  _ax[0].plot(beps_wv, _poly_off, color=color[l1//15*i], lw=2)
  _ax[1].plot(beps_wv, _freq_off, color=color[l1//15*i], lw=2)
  _ax[2].plot(beps_wv, _poly_on, color=color[l1//15*i], lw=2)
  _ax[3].plot(beps_wv, _freq_on, color=color[l1//15*i], lw=2)
fig.suptitle("Blue--> Red corresponds to 20% Sm --> 0% Sm", fontsize=20)
# Out:
# Text(0.5, 0.98, 'Blue--> Red corresponds to 20% Sm --> 0% Sm')

# %% [markdown]
# ### VAE

# %%
signal = poly_off#poly_off #choose the signal for VAE

_, norm_poly = normalize(signal)
vae_data = torch.tensor(norm_poly, dtype=torch.float)
print(vae_data.shape)
vae_loader = pv.utils.init_dataloader(vae_data, batch_size=12)
# Out:
# torch.Size([94, 320])

# %%
#VAE input dimension
in_dim = (signal.shape[1],)

vae = pv.models.iVAE(in_dim, latent_dim=2, invariances=None,
                      sampler_d='gaussian', decoder_sig=0.01, seed=42)
# Initialize SVI trainer
trainer = pv.trainers.SVItrainer(vae)

# Train for n epochs:
for e in range(200):
    trainer.step(vae_loader, scale_factor=1)
    trainer.print_statistics()
# Out:
# Epoch: 1 Training loss: 48753.8342
# Epoch: 2 Training loss: 24675.1389
# Epoch: 3 Training loss: 17964.2561
# Epoch: 4 Training loss: 9276.9371
# Epoch: 5 Training loss: 7644.5366
# Epoch: 6 Training loss: 4841.1793
# Epoch: 7 Training loss: 3797.3448
# Epoch: 8 Training loss: 3743.7652
# Epoch: 9 Training loss: 3439.3310
# Epoch: 10 Training loss: 3314.1183
# Epoch: 11 Training loss: 3466.1471
# Epoch: 12 Training loss: 3431.6690
# Epoch: 13 Training loss: 3205.3053
# Epoch: 14 Training loss: 3716.6610
# Epoch: 15 Training loss: 3461.8417
# Epoch: 16 Training loss: 3329.9550
# Epoch: 17 Training loss: 3178.3799
# Epoch: 18 Training loss: 2935.8641
# Epoch: 19 Training loss: 3040.9766
# Epoch: 20 Training loss: 2846.2831
# Epoch: 21 Training loss: 2859.1987
# Epoch: 22 Training loss: 2791.4238
# Epoch: 23 Training loss: 2722.1029
# Epoch: 24 Training loss: 2695.8775
# Epoch: 25 Training loss: 2654.4534
# Epoch: 26 Training loss: 2655.0791
# Epoch: 27 Training loss: 2588.9042
# Epoch: 28 Training loss: 2529.3551
# Epoch: 29 Training loss: 2618.2994
# Epoch: 30 Training loss: 2528.7503
# Epoch: 31 Training loss: 2456.0900
# Epoch: 32 Training loss: 2360.0145
# Epoch: 33 Training loss: 2413.5343
# Epoch: 34 Training loss: 2734.0330
# Epoch: 35 Training loss: 2402.1243
# Epoch: 36 Training loss: 2338.7988
# Epoch: 37 Training loss: 2264.5120
# Epoch: 38 Training loss: 2292.7483
# Epoch: 39 Training loss: 2221.1469
# Epoch: 40 Training loss: 2155.2164
# Epoch: 41 Training loss: 2190.9103
# Epoch: 42 Training loss: 2186.5928
# Epoch: 43 Training loss: 2342.3042
# Epoch: 44 Training loss: 2425.5331
# Epoch: 45 Training loss: 2216.6638
# Epoch: 46 Training loss: 2202.6123
# Epoch: 47 Training loss: 2152.7645
# Epoch: 48 Training loss: 2205.8834
# Epoch: 49 Training loss: 2346.8280
# Epoch: 50 Training loss: 2306.6947
# Epoch: 51 Training loss: 2409.7933
# Epoch: 52 Training loss: 2487.8877
# Epoch: 53 Training loss: 2235.6741
# Epoch: 54 Training loss: 2141.7436
# Epoch: 55 Training loss: 2077.6138
# Epoch: 56 Training loss: 2041.2829
# Epoch: 57 Training loss: 2164.1531
# Epoch: 58 Training loss: 2219.9527
# Epoch: 59 Training loss: 2175.0387
# Epoch: 60 Training loss: 2188.8038
# Epoch: 61 Training loss: 2233.1207
# Epoch: 62 Training loss: 2080.1867
# Epoch: 63 Training loss: 1959.5442
# Epoch: 64 Training loss: 1944.9275
# Epoch: 65 Training loss: 1880.5484
# Epoch: 66 Training loss: 1960.0988
# Epoch: 67 Training loss: 2163.0428
# Epoch: 68 Training loss: 1979.5078
# Epoch: 69 Training loss: 1850.6315
# Epoch: 70 Training loss: 1951.4605
# Epoch: 71 Training loss: 2625.0750
# Epoch: 72 Training loss: 2265.4352
# Epoch: 73 Training loss: 1982.3314
# Epoch: 74 Training loss: 1984.7881
# Epoch: 75 Training loss: 1904.3031
# Epoch: 76 Training loss: 2252.6773
# Epoch: 77 Training loss: 1995.5844
# Epoch: 78 Training loss: 2053.6556
# Epoch: 79 Training loss: 1882.8441
# Epoch: 80 Training loss: 1870.5731
# Epoch: 81 Training loss: 1898.9183
# Epoch: 82 Training loss: 1921.3467
# Epoch: 83 Training loss: 2018.0416
# Epoch: 84 Training loss: 1810.7078
# Epoch: 85 Training loss: 1840.9104
# Epoch: 86 Training loss: 1749.1889
# Epoch: 87 Training loss: 1671.6378
# Epoch: 88 Training loss: 1693.6790
# Epoch: 89 Training loss: 1628.9156
# Epoch: 90 Training loss: 1574.4397
# Epoch: 91 Training loss: 1557.3398
# Epoch: 92 Training loss: 1525.4014
# Epoch: 93 Training loss: 1707.4067
# Epoch: 94 Training loss: 1665.6804
# Epoch: 95 Training loss: 1612.3400
# Epoch: 96 Training loss: 1595.3232
# Epoch: 97 Training loss: 1486.2230
# Epoch: 98 Training loss: 1525.5806
# Epoch: 99 Training loss: 1458.3234
# Epoch: 100 Training loss: 1511.4556
# Epoch: 101 Training loss: 1546.3271
# Epoch: 102 Training loss: 1458.8198
# Epoch: 103 Training loss: 1444.9979
# Epoch: 104 Training loss: 1448.9356
# Epoch: 105 Training loss: 1471.4341
# Epoch: 106 Training loss: 1518.6974
# Epoch: 107 Training loss: 1572.6224
# Epoch: 108 Training loss: 1420.5737
# Epoch: 109 Training loss: 1416.4934
# Epoch: 110 Training loss: 1377.9495
# Epoch: 111 Training loss: 1424.0719
# Epoch: 112 Training loss: 1404.8108
# Epoch: 113 Training loss: 1440.7535
# Epoch: 114 Training loss: 1400.4231
# Epoch: 115 Training loss: 1546.8716
# Epoch: 116 Training loss: 1447.8037
# Epoch: 117 Training loss: 1629.4783
# Epoch: 118 Training loss: 1645.0267
# Epoch: 119 Training loss: 1515.8210
# Epoch: 120 Training loss: 1489.2374
# Epoch: 121 Training loss: 1506.7950
# Epoch: 122 Training loss: 1429.5418
# Epoch: 123 Training loss: 1481.9185
# Epoch: 124 Training loss: 1580.5054
# Epoch: 125 Training loss: 1485.0001
# Epoch: 126 Training loss: 1400.4854
# Epoch: 127 Training loss: 1365.1026
# Epoch: 128 Training loss: 1349.5111
# Epoch: 129 Training loss: 1445.0155
# Epoch: 130 Training loss: 1414.4644
# Epoch: 131 Training loss: 1338.7820
# Epoch: 132 Training loss: 1301.8185
# Epoch: 133 Training loss: 1315.8448
# Epoch: 134 Training loss: 1317.9505
# Epoch: 135 Training loss: 1334.7759
# Epoch: 136 Training loss: 1379.8798
# Epoch: 137 Training loss: 1366.9230
# Epoch: 138 Training loss: 1344.3921
# Epoch: 139 Training loss: 1373.6874
# Epoch: 140 Training loss: 1443.3359
# Epoch: 141 Training loss: 1379.7685
# Epoch: 142 Training loss: 1439.0153
# Epoch: 143 Training loss: 1359.6454
# Epoch: 144 Training loss: 1342.4181
# Epoch: 145 Training loss: 1352.6965
# Epoch: 146 Training loss: 1391.9066
# Epoch: 147 Training loss: 1349.5936
# Epoch: 148 Training loss: 1313.3555
# Epoch: 149 Training loss: 1338.3395
# Epoch: 150 Training loss: 1348.5503
# Epoch: 151 Training loss: 1306.9916
# Epoch: 152 Training loss: 1343.7722
# Epoch: 153 Training loss: 1372.6491
# Epoch: 154 Training loss: 1382.2454
# Epoch: 155 Training loss: 1412.3143
# Epoch: 156 Training loss: 1473.4052
# Epoch: 157 Training loss: 1290.2825
# Epoch: 158 Training loss: 1304.7886
# Epoch: 159 Training loss: 1260.1817
# Epoch: 160 Training loss: 1272.1580
# Epoch: 161 Training loss: 1256.8207
# Epoch: 162 Training loss: 1248.8510
# Epoch: 163 Training loss: 1242.1099
# Epoch: 164 Training loss: 1249.4233
# Epoch: 165 Training loss: 1274.5632
# Epoch: 166 Training loss: 1281.6486
# Epoch: 167 Training loss: 1260.8762
# Epoch: 168 Training loss: 1282.5535
# Epoch: 169 Training loss: 1268.1977
# Epoch: 170 Training loss: 1289.9428
# Epoch: 171 Training loss: 1269.0321
# Epoch: 172 Training loss: 1277.9560
# Epoch: 173 Training loss: 1226.0669
# Epoch: 174 Training loss: 1231.2141
# Epoch: 175 Training loss: 1299.4025
# Epoch: 176 Training loss: 1234.2245
# Epoch: 177 Training loss: 1246.3431
# Epoch: 178 Training loss: 1278.7973
# Epoch: 179 Training loss: 1223.5483
# Epoch: 180 Training loss: 1203.3074
# Epoch: 181 Training loss: 1289.3763
# Epoch: 182 Training loss: 1357.9654
# Epoch: 183 Training loss: 1266.2617
# Epoch: 184 Training loss: 1235.5272
# Epoch: 185 Training loss: 1236.9209
# Epoch: 186 Training loss: 1246.0153
# Epoch: 187 Training loss: 1236.4168
# Epoch: 188 Training loss: 1330.1982
# Epoch: 189 Training loss: 1337.7387
# Epoch: 190 Training loss: 1311.5880
# Epoch: 191 Training loss: 1268.1107
# Epoch: 192 Training loss: 1230.3020
# Epoch: 193 Training loss: 1216.3727
# Epoch: 194 Training loss: 1227.9702
# Epoch: 195 Training loss: 1286.9656
# Epoch: 196 Training loss: 1308.9646
# Epoch: 197 Training loss: 1203.3936
# Epoch: 198 Training loss: 1197.1969
# Epoch: 199 Training loss: 1198.1958
# Epoch: 200 Training loss: 1165.5356

# %%
z_mean, z_std = vae.encode(vae_data)

z1 = z_mean[:, -2]
z2 = z_mean[:, -1]

# %%
fig = plt.figure(figsize=(5, 5))
plt.scatter(z2, z1, s=10, color='deepskyblue', lw=0.3, edgecolor='black')
plt.xlabel("$z_2$", fontsize=14)
plt.ylabel("$z_1$", fontsize=14)
plt.title('GT VAE BEPS')
# Out:
# Text(0.5, 1.0, 'GT VAE BEPS')

# %%
vae.manifold2d(d=10)
# Out:
# tensor([[0.4901, 0.4869, 0.5290,  ..., 0.0818, 0.0807, 0.0729],
#         [0.4770, 0.4807, 0.5378,  ..., 0.0969, 0.0973, 0.0956],
#         [0.4637, 0.4796, 0.5390,  ..., 0.1153, 0.1187, 0.1213],
#         ...,
#         [0.4427, 0.4114, 0.4489,  ..., 0.3531, 0.3187, 0.3054],
#         [0.4507, 0.4329, 0.4544,  ..., 0.3882, 0.3574, 0.3453],
#         [0.4615, 0.4657, 0.4601,  ..., 0.4611, 0.4453, 0.4415]])

# %%
fig, ax = plt.subplots(2, 1, figsize=(9, 4))

ax[0].plot(z1, color='red')
ax[1].plot(z2, color='green')

ax[0].set_ylabel('z$_1$', fontsize=12)
ax[1].set_ylabel('z$_2$', fontsize=12)

for _ in ax.flat:
  _.set_xlim(0,len(z1))
  _.grid()
  _.set_xlabel('Loop number', fontsize=12)

# %% [markdown]
# # The orchestrated experiment

# %%
#@title VAE & GP functions

from ast import Pass
from gpax import ExactGP
from pyroved.models import iVAE
from typing import Callable, Dict, Optional

#----------- VAE -------------
def VAE(dataset, batch_size=12, latent_dim=2, n_epoch=200, print_statistics=False, test = None):
  norm_coef, norm_data = normalize(dataset)

  vae_data = torch.tensor(norm_data, dtype=torch.float)
  vae_loader = pv.utils.init_dataloader(vae_data)

  in_dim = (dataset.shape[1],)

  vae = pv.models.iVAE(in_dim, latent_dim=latent_dim, invariances=None,
                      sampler_d='gaussian', decoder_sig=0.01, seed=42)

  # Initialize SVI trainer
  trainer = pv.trainers.SVItrainer(vae)

  # Train for n epochs:
  for e in range(n_epoch):
    trainer.step(vae_loader, scale_factor=1)
    if print_statistics:
      trainer.print_statistics()
  if not print_statistics:
    trainer.print_statistics()

  if type(test) !=type(None):
    test_norm = (test - norm_coef[0])/norm_coef[1]
    vae_full = torch.tensor(test_norm, dtype=torch.float)
    full_mean, full_std = vae.encode(vae_full)
    return norm_coef, (full_mean, full_std)
  else:
    z_mean, z_std = vae.encode(vae_data)
    return norm_coef, (z_mean, z_std)

def plot_ld(train, test = None, highlight_latest=True, return_fig=False):
  """
        Plot VAE latent distribution

        Parameters
        ----------
        train: dataset used to train VAE

        test:  full dataset, if available

        highlight_latest: emphasis point, correspondent to the last selected location

        return_fig: return fig object (required if we would like to make video)

        Returns
        -------
        None of plt.fig

  """
  fig, ax = plt.subplots(figsize=(4, 4), dpi=100)
  fig.subplots_adjust(wspace=.3)

  if test is not None:
    ax.scatter(test[:,-2], test[:,-1], color='grey', s=3)
  ax.scatter(train[:,-2], train[:,-1], color='red', s=20, label = 'training')
  if highlight_latest:
    ax.scatter(train[-1,-2], train[-1,-1], color='red', s=60, marker='x', label = 'last_added_point')


  ax.legend()
  for _ in [ax,]:
    _.grid()
    _.set_xlabel('z1')
    _.set_ylabel('z2')
    _.tick_params('both', direction='in')
  plt.show()

  if return_fig:
    return fig


#----------- GP BO -------------

class Orchestrated_BO(ExactGP):
  def __init__(self,
               kernel='Matern',
               lengthscale_prior_dist = None,
               noise_prior_dist = None,
               mean_fn = None,
               mean_fn_prior = None):

     super().__init__(1, kernel=kernel,
                         lengthscale_prior_dist=lengthscale_prior_dist,
                         noise_prior_dist = noise_prior_dist,
                         mean_fn = mean_fn,
                         mean_fn_prior = mean_fn_prior)
     self.keys = gpax.utils.get_keys(1)
     self.X_test  = None
     self.X_train = None
     self.y_train = None

  def iteration(self, X_train, y_train, X_test):
    self.X_test  = X_test
    self.X_train = X_train
    self.y_train = y_train

    self.fit(self.keys[0], X_train, y_train)
    self.y_mean, self.y_sampled = self.predict(self.keys[1], X_test, noiseless=True)

  def visualize_res(self, vae_latents=[], **kwargs):
    if self.X_test is None:
      raise ValueError('You must perform iteration first')

    fig = plt.figure(figsize=(6, 4))
    plt.plot(self.y_mean, c='red', label='Prediction')
    plt.fill_between(self.X_test,
                      self.y_mean - self.y_sampled.squeeze().std(0),
                      self.y_mean + self.y_sampled.squeeze().std(0),
                      alpha=0.3, color='red')

    plt.scatter(self.X_train,
                self.y_train,
                c='red',
                label='Experiment',
                alpha=0.6)
    if len(vae_latents) > 0:
        plt.plot(self.X_test,
                 vae_latents, '--',
                 color='black',
                 label='Ground Truth',
                 alpha=0.5)

    plt.legend(loc='lower center', fontsize=8, ncol=3)
    plt.grid(True)
    plt.show()
    return fig


  def acquisition(self, acq_func='EI', maximize=True, visualize=False):
    if acquisition_function == 'EI':
      _acq = gpax.acquisition.EI(self.keys[1], gp_model, self.X_test, maximize=maximize, noiseless=True)
    elif acquisition_function == 'MU':
      _acq = gpax.acquisition.MU(self.keys[1], gp_model, self.X_test, maximize=maximize, noiseless=True)
    elif acquisition_function == 'UCB':
      _acq = gpax.acquisition.UCB(self.keys[1], gp_model, self.X_test, maximize=maximize, noiseless=True)
    else:
      raise ValueError('Unknown acquisition function')

    _acq = np.array(_acq)
    _acq[np.isnan(_acq)==True] = np.random.uniform(low=0.0, high=1.0, size=_acq[np.isnan(_acq)==True].shape)*1e-3
    self.acq = _acq

    maxacq_idx = _acq.argmax()
    maxacq_val = _acq.max()
    self.nextpt = self.X_test[maxacq_idx]

    fig = None
    if visualize:
      fig = self.vis_acq(nextpt=self.nextpt, maxacq_val=maxacq_val)

    return maxacq_idx, maxacq_val, fig



  def vis_acq(self, nextpt=None, maxacq_val=None):
    fig = plt.figure(figsize=(6, 4))
    plt.plot(self.acq, c='r', label="Acquisition function")

    if (nextpt is not None) and (maxacq_val is not None):
      plt.scatter(x=nextpt, y=maxacq_val, color='k', marker = 'X', s=100, label="Next point")

    plt.legend(loc='lower center', fontsize=8)
    plt.title("Acquisition function")
    plt.grid()
    plt.show()
    return fig

  def get_statistics(self,):
    dict_res = {}

    dict_res['X_train']       = np.array(self.X_train).astype(int)
    dict_res['y_train']       = np.array(self.y_train).astype(float)

    dict_res['X_test']        = np.array(self.X_test).astype(int)

    dict_res['noise']         = self.get_samples(1)['noise'].squeeze().mean(0).astype(float)
    dict_res['k_length']      = self.get_samples(1)['k_length'].squeeze().mean(0).astype(float)

    dict_res['y_res_mean']    = np.array(self.y_mean).astype(float)
    dict_res['y_res_uncertainty'] = np.array(tuple(x.squeeze().std(0) for x in self.y_sampled)).astype(float)
    dict_res['next_point'] = np.array(self.nextpt).astype(int)

    return dict_res

# %%
#@title auxiliary functions

import h5py

def convert_to_supported_dtype(arr):
    # Check if array has an object dtype
    if arr.dtype == np.dtype('O'):
        # Attempt conversion to a compatible type (if possible)
        try:
            return arr.astype(np.float64)  # Change to a compatible type (e.g., float)
        except ValueError:
            raise ValueError(f"Cannot convert array '{arr}' to a supported dtype.")
    return arr

def save_dict_to_hdf5(file_path, data_dict):
    def save_data(group, data):
        for key, value in data.items():
            if isinstance(value, dict):
                subgroup = group.create_group(key)
                save_data(subgroup, value)
            elif isinstance(value, np.ndarray):
                # Check and convert object dtype arrays if needed
                value = convert_to_supported_dtype(value)
                group.create_dataset(key, data=value)
            else:
                # Handle other types of data or metadata as needed
                pass

    with h5py.File(file_path, 'w') as f:
        save_data(f, data_dict)

def load_hdf5_to_dict(file_path):
    def load_data(group):
        data = {}
        for key, item in group.items():
            if isinstance(item, h5py.Group):
                data[key] = load_data(item)
            else:
                data[key] = np.array(item)
        return data

    with h5py.File(file_path, 'r') as f:
        data_dict = load_data(f)

    return data_dict

def make_video(path, fig_list, fps=1):
  llist = []
  for f in fig_list:
    f.canvas.draw()
    rgb_array = np.frombuffer(f.canvas.tostring_rgb(), dtype=np.uint8)
    rgb_array = rgb_array.reshape(f.canvas.get_width_height()[::-1] + (3,))
    llist.append(rgb_array)

    imageio.mimwrite(path, llist , fps = fps)

# %% [markdown]
# Set scalarizer

# %%
scalarizer = poly_off

# %% [markdown]
# Set the priors below

# %%
#Priors:  None for default choice or select smth specific

#number of initial measurements (no less than 3)
N_seeds = 3
N_seeds = max(N_seeds, 3)

#VAE
latent_dim = 2
n_epoch = 200

#GP inputs
latent_for_gp = -1 #select vae latent to train gp

#lengthscale_prior_dist
ls = dist.Uniform(0, 30)
#noise prior
noise_prior = dist.HalfNormal(0.3)

mean_fn       = None
mean_fn_prior = None

acquisition_function = 'EI' #or 'UCB', or 'MU'
maximize = True #maximize or minimize acq. func.


#number of exploration steps
N_iteration = 10

# %% [markdown]
# Execute the following cell in case of sGP.

# %%
#example of priors for structured GP
from typing import Dict

import numpyro
import jax.numpy as jnp

def piecewise(x: jnp.ndarray, params: Dict[str, float]) -> jnp.ndarray:
    """Power-law behavior before and after the transition"""
    return jnp.piecewise(
        x, [x < params["t"], x >= params["t"]],
        [lambda x: x**params["beta1"], lambda x: x**params["beta2"]])


def piecewise_priors():
    # Sample model parameters
    t = numpyro.sample("t", numpyro.distributions.Uniform(40, 80))
    beta1 = numpyro.sample("beta1", numpyro.distributions.LogNormal(0, 1))
    beta2 = numpyro.sample("beta2", numpyro.distributions.LogNormal(0, 1))
    # Return sampled parameters as a dictionary
    return {"t": t, "beta1": beta1, "beta2": beta2}


mean_fn       = piecewise
mean_fn_prior = piecewise_priors

# %%
#@title processing
#-------------------------------------------------------
fig_vae = []
fig_acq = []
fig_gp = []

res_stats = {}
#-------------------------------------------------------


X_test = np.arange(len(scalarizer))

#random initial locations including both edges
X_train = np.random.choice(np.arange(1,len(scalarizer)-1), size=N_seeds-2, replace=False)
X_train = np.append(X_train, [0, scalarizer.shape[0]-1])

#VAE train
VAE_train = scalarizer[X_train]

print(f'\n-- VAE (seed locations) --')

_, (z_mean, z_std) = VAE(VAE_train, latent_dim=latent_dim, n_epoch=n_epoch, test=scalarizer)

#z_mean_train is available in the real experiment
z_mean_train = z_mean[X_train]

fig = plot_ld(train = z_mean_train, test = z_mean, return_fig=True, highlight_latest=False)
fig.suptitle('Iteration 0')
fig_vae.append(fig)

#y train for GP
GP_train = z_mean_train[:, latent_for_gp]

#iterations
for iter in range(N_iteration):

  print(f'\n------ Iteration {iter+1} --------')

  #save current state
  res_stats[f'iter {iter}'] = {'VAE':      np.array(z_mean_train).astype(float),
                               'VAE_full': np.array(z_mean).astype(float),}


#VAE
  if iter > 0:
    print(f'\n-- VAE iteration {iter+1}) --\n')
    X_train = np.append(X_train, X_test[maxacq_idx])

    VAE_train = np.append(VAE_train, scalarizer[next_idx][np.newaxis, :], axis=0)

    _, (z_mean, z_std) = VAE(VAE_train, latent_dim=latent_dim, n_epoch=n_epoch, test=scalarizer)

    z_mean_train = z_mean[X_train]

    fig = plot_ld(train = z_mean_train, test = z_mean, return_fig=True)
    fig.suptitle('Iteration {}'.format(iter))
    fig_vae.append(fig)

    #GP_train = np.append(GP_train, 0)
    GP_train = z_mean_train[:,latent_for_gp].squeeze()

#GP BO
  gp_model = Orchestrated_BO(kernel='RBF',
                             lengthscale_prior_dist = ls,
                              noise_prior_dist = noise_prior,
                             mean_fn = mean_fn,
                             mean_fn_prior = mean_fn_prior)

  gp_model.iteration(X_train, np.array(GP_train), X_test)

  fig = gp_model.visualize_res(vae_latents=z_mean[:,latent_for_gp])
  fig_gp.append(fig)

  maxacq_idx, maxacq_val,fig = gp_model.acquisition(acq_func=acquisition_function,
                                                    maximize=True,
                                                    visualize=True)
  fig_acq.append(fig)

  next_idx = X_test[maxacq_idx]

  res_stats[f'iter {iter}'].update(gp_model.get_statistics())
# Out:
# -- VAE (seed locations) --
# Epoch: 200 Training loss: -1036.8226
# ------ Iteration 1 --------
# sample: 100%|██████████| 4000/4000 [00:04<00:00, 863.31it/s, 7 steps of size 4.29e-01. acc. prob=0.92]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     13.97      8.19     13.60      0.15     25.97   1744.47      1.00
#     k_scale      1.57      1.33      1.20      0.09      3.16   1298.51      1.00
#       noise      0.27      0.20      0.23      0.00      0.55   1085.80      1.00
# ------ Iteration 2 --------
#
# -- VAE iteration 2) --
#
# Epoch: 200 Training loss: -451.8042
# sample: 100%|██████████| 4000/4000 [00:05<00:00, 759.05it/s, 3 steps of size 4.70e-01. acc. prob=0.89]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     18.83      7.89     20.16      7.18     29.95   1508.02      1.00
#     k_scale      3.80      2.49      3.19      0.79      6.71   1175.82      1.00
#       noise      0.26      0.19      0.23      0.00      0.52    862.15      1.00
# ------ Iteration 3 --------
#
# -- VAE iteration 3) --
#
# Epoch: 200 Training loss: -249.9418
# sample: 100%|██████████| 4000/4000 [00:05<00:00, 716.42it/s, 3 steps of size 5.08e-01. acc. prob=0.92]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     15.45      8.44     15.49      3.53     29.86   1700.79      1.00
#     k_scale      0.55      0.50      0.41      0.05      1.13   1377.54      1.00
#       noise      0.18      0.15      0.14      0.00      0.40   1361.08      1.00
# ------ Iteration 4 --------
#
# -- VAE iteration 4) --
#
# Epoch: 200 Training loss: 11.0269
# sample: 100%|██████████| 4000/4000 [00:06<00:00, 661.12it/s, 3 steps of size 2.93e-01. acc. prob=0.95]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     14.66      8.05     15.04      0.76     26.53    834.44      1.00
#     k_scale      1.39      0.98      1.10      0.20      2.74    946.27      1.00
#       noise      0.18      0.17      0.13      0.00      0.41    857.18      1.00
# ------ Iteration 5 --------
#
# -- VAE iteration 5) --
#
# Epoch: 200 Training loss: 91.9291
# sample: 100%|██████████| 4000/4000 [00:06<00:00, 661.95it/s, 3 steps of size 4.46e-01. acc. prob=0.86]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     19.35      6.46     20.14     10.69     29.95    759.92      1.00
#     k_scale      1.30      0.99      1.01      0.23      2.45   1012.85      1.00
#       noise      0.10      0.13      0.06      0.00      0.28   1001.17      1.01
# ------ Iteration 6 --------
#
# -- VAE iteration 6) --
#
# Epoch: 200 Training loss: -360.9791
# sample: 100%|██████████| 4000/4000 [00:08<00:00, 451.09it/s, 7 steps of size 4.14e-01. acc. prob=0.84]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     19.97      4.46     19.88     13.02     28.07    441.22      1.00
#     k_scale      3.60      2.58      2.95      1.05      6.29    426.76      1.00
#       noise      0.06      0.11      0.01      0.00      0.21    654.92      1.00
# ------ Iteration 7 --------
#
# -- VAE iteration 7) --
#
# Epoch: 200 Training loss: 530.9087
# sample: 100%|██████████| 4000/4000 [00:09<00:00, 400.49it/s, 7 steps of size 3.24e-01. acc. prob=0.93]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     21.40      4.59     20.95     15.89     29.82    649.10      1.00
#     k_scale      1.39      0.86      1.19      0.31      2.36   1048.34      1.00
#       noise      0.03      0.06      0.01      0.00      0.09   1410.37      1.00
# ------ Iteration 8 --------
#
# -- VAE iteration 8) --
#
# Epoch: 200 Training loss: 493.9242
# sample: 100%|██████████| 4000/4000 [00:06<00:00, 592.14it/s, 7 steps of size 2.98e-01. acc. prob=0.95]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     20.07      4.16     19.38     13.92     27.83    639.56      1.00
#     k_scale      1.16      0.72      0.96      0.30      2.07    911.62      1.00
#       noise      0.02      0.04      0.00      0.00      0.05   1220.87      1.00
# ------ Iteration 9 --------
#
# -- VAE iteration 9) --
#
# Epoch: 200 Training loss: 1335.4844
# sample: 100%|██████████| 4000/4000 [00:05<00:00, 734.06it/s, 7 steps of size 5.53e-01. acc. prob=0.93]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     25.72      3.36     26.51     20.85     29.98   1613.03      1.00
#     k_scale      0.45      0.32      0.36      0.09      0.85   1310.99      1.00
#       noise      0.00      0.00      0.00      0.00      0.01   1042.48      1.00
# ------ Iteration 10 --------
#
# -- VAE iteration 10) --
#
# Epoch: 200 Training loss: 479.5294
# sample: 100%|██████████| 4000/4000 [00:05<00:00, 720.34it/s, 7 steps of size 5.10e-01. acc. prob=0.90]
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
# k_length[0]     23.66      3.73     23.65     18.79     29.99   1081.32      1.00
#     k_scale      2.96      1.66      2.56      0.97      5.07   1387.46      1.00
#       noise      0.03      0.03      0.02      0.00      0.05    973.90      1.00

# %%
#save results
save_dict_to_hdf5('res.h5', res_stats)

# %%
#save figures to the directory

# !mkdir figs

for i in range(len(fig_acq)):
  fig_acq[i].savefig('figs/acq_iter_{}.jpeg'.format(i), dpi=300, bbox_inches='tight')
  fig_vae[i].savefig('figs/vae_iter_{}.jpeg'.format(i), dpi=300, bbox_inches='tight')
  fig_gp[i].savefig('figs/gp_iter_{}.jpeg'.format(i), dpi=300, bbox_inches='tight')

# %% [markdown]
# ### make videofiles

# %%
make_video('vae.mp4', fig_vae, fps=1);

# %%
Video('vae.mp4', embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
frame_list = []
for i in range(len(fig_gp)):
  fig_gp[i].set_dpi(100)
  fig_gp[i].suptitle('Iteration {}'.format(i))
  fig_gp[i].canvas.draw()
  rgb_gp = np.frombuffer(fig_gp[i].canvas.tostring_rgb(), dtype=np.uint8)
  rgb_gp = rgb_gp.reshape(fig_gp[i].canvas.get_width_height()[::-1] + (3,))

  fig_acq[i].set_dpi(100)
  fig_acq[i].canvas.draw()
  rgb_acq = np.frombuffer(fig_acq[i].canvas.tostring_rgb(), dtype=np.uint8)
  rgb_acq = rgb_acq.reshape(fig_acq[i].canvas.get_width_height()[::-1] + (3,))

  frame_list.append(np.concatenate([rgb_gp, rgb_acq], axis=1))

imageio.mimwrite('gp.mp4', frame_list , fps = 1)

# %%
Video('gp.mp4', embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
